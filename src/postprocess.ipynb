# %%
import pandas as pd
import os

results_path = "/workspace/company/math_scoring_with_gpt/results"
post_results_path = "/workspace/company/math_scoring_with_gpt/post_results"

# %% [markdown]
# # 1-1

# %%
import pandas as pd
import os

results_path = "/workspace/company/math_scoring_with_gpt/results"
post_results_path = "/workspace/company/math_scoring_with_gpt/post_results"

# %%
number_1_1_path = os.path.join(results_path, "number_1_1_eval.tsv")

print(number_1_1_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_1_1_eval.tsv

# %%
df_1_1 = pd.read_csv(number_1_1_path, sep="\t")

df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...

# %%
# \n\n -> \n
df_1_1['bot_response'] = df_1_1['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...

# %%
# df_1_1['bot_response'] split by \n
df_1_1['bot_response_split'] = df_1_1['bot_response'].apply(lambda x: x.split("\n"))

# %%
df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...  \
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...
#
#                                   bot_response_split
# 0  [점수: 0, 이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도...
# 1  [점수: 0, 이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알...
# 2  [점수: 2, 이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언...
# 3  [점수: 1, 이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다...
# ...

# %%
# make new two columns using bot_response_split column, which is a list
df_1_1['score'] = df_1_1['bot_response_split'].apply(lambda x: x[0])
df_1_1['reason'] = df_1_1['bot_response_split'].apply(lambda x: x[1])

df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...  \
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...
#
#                                   bot_response_split  score
# 0  [점수: 0, 이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도...  점수: 0  \
# 1  [점수: 0, 이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알...  점수: 0
# 2  [점수: 2, 이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언...  점수: 2
# ...

# %%
# preprocessing in score column, erase "점수: "
df_1_1['score'] = df_1_1['score'].apply(lambda x: x.replace("점수: ", ""))

df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...  \
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도...     0  \
# 1  [점수: 0, 이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알...     0
# 2  [점수: 2, 이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언...     2
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_1_1['reason'] = df_1_1['reason'].apply(lambda x: x.replace("이유: ", ""))

df_1_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식  \
# 1        2                                     윗면과 아랫면이 평행한 것
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...
# 3        4                                       한 변이 평행한 사각형
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다
#
#                                         bot_response
# 0  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 ...  \
# 1  점수: 0\n이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고...
# 2  점수: 2\n이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급...
# 3  점수: 1\n이유: 사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다....
# 4  점수: 0\n이유: 사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바...
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도...     0  \
# 1  [점수: 0, 이유: 사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알...     0
# 2  [점수: 2, 이유: 사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언...     2
# ...

# %%
df_1_1_pre = df_1_1[['user_id', 'user_answer', 'score', 'reason']]

df_1_1_pre.head()
# Out:
#    user_id                                        user_answer score
# 0        1                                수직선에서 밑으로 넓게 퍼지는 형식     0  \
# 1        2                                     윗면과 아랫면이 평행한 것     0
# 2        3  변이 네개고 각이 네개인 도형(사각형) 중에서 평행한 변이 한 쌍이라도 있는 도형을...     2
# 3        4                                       한 변이 평행한 사각형     1
# 4        5                             윗변과 아랫변은 평행관계이고 수직관계이다     0
#
#                                               reason
# 0         사다리꼴이 사각형임을 명시하지 않고, 평행한 변에 대한 설명도 하지 않았다.
# 1  사다리꼴이 사각형임을 알고 있지 않고, 평행한 변의 개념은 알고 있지만 정확한 정의...
# 2  사각형임을 알고 있으며 평행한 변의 성질에 대해서도 정확히 언급하였다. 따라서 답안...
# 3  사각형이라고 명시하였고, 평행한 변이 한 쌍인 것도 표현하였다. 그러나 "한쌍 내지...
# 4    사다리꼴이 사각형임을 명시하지 않았고, 평행한 변의 개념을 올바르게 설명하지 않았다.

# %%
df_1_1_pre_path = os.path.join(post_results_path, "number_1_1_eval_pre.tsv")

df_1_1_pre.to_csv(df_1_1_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 2-1

# %%
number_2_1_path = os.path.join(results_path, "number_2_1_eval.tsv")

print(number_2_1_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_2_1_eval.tsv

# %%
df_2_1 = pd.read_csv(number_2_1_path, sep="\t")

df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.

# %%
# \n\n -> \n
df_2_1['bot_response'] = df_2_1['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.

# %%
# df_1_1['bot_response'] split by \n
df_2_1['bot_response_split'] = df_2_1['bot_response'].apply(lambda x: x.split("\n"))

# %%
df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.  \
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.
#
#                                   bot_response_split
# 0             [점수: 2, 이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.]
# 1           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.]
# 2  [점수: 2, 이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 ...
# 3           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.]
# 4        [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.]

# %%
# make new two columns using bot_response_split column, which is a list
df_2_1['score'] = df_2_1['bot_response_split'].apply(lambda x: x[0])
df_2_1['reason'] = df_2_1['bot_response_split'].apply(lambda x: x[1])

df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.  \
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.
#
#                                   bot_response_split  score
# 0             [점수: 2, 이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.]  점수: 2  \
# 1           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.]  점수: 2
# 2  [점수: 2, 이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 ...  점수: 2
# 3           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.]  점수: 2
# 4        [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.]  점수: 2
#
#                                               reason
# ...

# %%
# preprocessing in score column, erase "점수: "
df_2_1['score'] = df_2_1['score'].apply(lambda x: x.replace("점수: ", ""))

df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.  \
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.
#
#                                   bot_response_split score
# 0             [점수: 2, 이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.]     2  \
# 1           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.]     2
# 2  [점수: 2, 이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 ...     2
# 3           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.]     2
# 4        [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.]     2
#
#                                               reason
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_2_1['reason'] = df_2_1['reason'].apply(lambda x: x.replace("이유: ", ""))

df_2_1.head()
# Out:
#    user_id          user_answer
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ
#
#                                         bot_response
# 0               점수: 2\n이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.  \
# 1             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  점수: 2\n이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기...
# 3             점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4          점수: 2\n이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.
#
#                                   bot_response_split score
# 0             [점수: 2, 이유: 정답과 일치하며 필요한 선분들을 모두 찾았다.]     2  \
# 1           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 올바르게 찾았다.]     2
# 2  [점수: 2, 이유: 학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 ...     2
# 3           [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾아내었다.]     2
# 4        [점수: 2, 이유: 정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.]     2
#
#                                               reason
# ...

# %%
df_2_1_pre = df_2_1[['user_id', 'user_answer', 'score', 'reason']]

df_2_1_pre.head()
# Out:
#    user_id          user_answer score
# 0        1  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ     2  \
# 1        2  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ     2
# 2        3  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ     2
# 3        4  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ     2
# 4        5  선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ     2
#
#                                               reason
# 0                          정답과 일치하며 필요한 선분들을 모두 찾았다.
# 1                        정답과 일치하며, 필요한 선분을 올바르게 찾았다.
# 2  학생이 선분 ㄱㄹ, 선분 ㄴㄷ, 선분 ㄱㅁ을 올바르게 찾아서 기호와 이름을 모두 정...
# 3                        정답과 일치하며, 필요한 선분을 모두 찾아내었다.
# 4                     정답과 일치하며, 필요한 선분을 모두 찾고 표기하였다.

# %%
df_2_1_pre_path = os.path.join(post_results_path, "number_2_1_eval_pre.tsv")

df_2_1_pre.to_csv(df_2_1_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 2-2

# %%
number_2_2_path = os.path.join(results_path, "number_2_2_eval.tsv")

print(number_2_2_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_2_2_eval.tsv

# %%
df_2_2 = pd.read_csv(number_2_2_path, sep="\t")

df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...

# %%
# \n\n -> \n
df_2_2['bot_response'] = df_2_2['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...

# %%
# df_1_1['bot_response'] split by \n
df_2_2['bot_response_split'] = df_2_2['bot_response'].apply(lambda x: x.split("\n"))

# %%
df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...  \
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...
#
#                                   bot_response_split
# 0  [점수: 0, 이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 ...
# 1  [점수: 2, 이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적...
# 2  [점수: 0, 이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫...
# 3  [점수: 0, 이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 ...
# 4  [점수: 2, 이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문...

# %%
# make new two columns using bot_response_split column, which is a list
df_2_2['score'] = df_2_2['bot_response_split'].apply(lambda x: x[0])
df_2_2['reason'] = df_2_2['bot_response_split'].apply(lambda x: x[1])

df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...  \
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...
#
#                                   bot_response_split  score
# 0  [점수: 0, 이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 ...  점수: 0  \
# 1  [점수: 2, 이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적...  점수: 2
# 2  [점수: 0, 이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫...  점수: 0
# 3  [점수: 0, 이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 ...  점수: 0
# 4  [점수: 2, 이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문...  점수: 2
#
#                                               reason
# ...

# %%
# preprocessing in score column, erase "점수: "
df_2_2['score'] = df_2_2['score'].apply(lambda x: x.replace("점수: ", ""))

df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...  \
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 ...     0  \
# 1  [점수: 2, 이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적...     2
# 2  [점수: 0, 이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫...     0
# 3  [점수: 0, 이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 ...     0
# 4  [점수: 2, 이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문...     2
#
#                                               reason
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_2_2['reason'] = df_2_2['reason'].apply(lambda x: x.replace("이유: ", ""))

df_2_2.head()
# Out:
#    user_id          user_answer
# 0        1   None,  None,  None  \
# 1        2        윗변,  아랫변,  높이
# 2        3        윗변,  아랫변,  높이
# 3        4        윗변,  아랫변,  높이
# 4        5        윗변,  아랫변,  높이
#
#                                         bot_response
# 0  점수: 0\n이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선...  \
# 1  점수: 2\n이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었...
# 2  점수: 0\n이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변...
# 3  점수: 0\n이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구...
# 4  점수: 2\n이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에...
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 ...     0  \
# 1  [점수: 2, 이유: 문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적...     2
# 2  [점수: 0, 이유: 학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫...     0
# 3  [점수: 0, 이유: 문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 ...     0
# 4  [점수: 2, 이유: 문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문...     2
#
#                                               reason
# ...

# %%
df_2_2_pre = df_2_2[['user_id', 'user_answer', 'score', 'reason']]

df_2_2_pre.head()
# Out:
#    user_id          user_answer score
# 0        1   None,  None,  None     0  \
# 1        2        윗변,  아랫변,  높이     2
# 2        3        윗변,  아랫변,  높이     0
# 3        4        윗변,  아랫변,  높이     0
# 4        5        윗변,  아랫변,  높이     2
#
#                                               reason
# 0  정답 중 일치하는 항목이 없고, None으로 작성되어 있어서 선분 이름과 길이에 대...
# 1  문제에서 요구하는 선분의 기능에 대한 용어를 모두 정확하게 적었다. (윗변, 아랫변...
# 2  학생은 사다리꼴 넓이를 구하는데 필요한 선분들을 '윗변, 아랫변, 높이'라고 적었지...
# 3     문제에서 요구한 선분의 기호와 이름을 적지 않았으며, 길이를 구하는 것도 빠져있다.
# 4  문제에서 요구하는 선분에 대응하는 용어를 정확하게 적었기 때문에, 학생이 사다리꼴의...

# %%
df_2_2_pre_path = os.path.join(post_results_path, "number_2_2_eval_pre.tsv")

df_2_2_pre.to_csv(df_2_2_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 2-3

# %%
number_2_3_path = os.path.join(results_path, "number_2_3_eval.tsv")

print(number_2_3_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_2_3_eval.tsv

# %%
df_2_3 = pd.read_csv(number_2_3_path, sep="\t")

df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...

# %%
# \n\n -> \n
df_2_3['bot_response'] = df_2_3['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...

# %%
# df_1_1['bot_response'] split by \n
df_2_3['bot_response_split'] = df_2_3['bot_response'].apply(lambda x: x.split("\n"))
df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.  \
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...
#
#                                   bot_response_split
# 0                  [점수: 2, 이유: 모든 선분의 길이를 올바르게 구했다.]
# 1  [0점, 이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적...
# 2  [1점, 이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 ...
# 3        [점수: 2, 이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.]
# 4  [점수: 0, 이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적...

# %%
# make new two columns using bot_response_split column, which is a list
df_2_3['score'] = df_2_3['bot_response_split'].apply(lambda x: x[0])
df_2_3['reason'] = df_2_3['bot_response_split'].apply(lambda x: x[1])

df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.  \
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...
#
#                                   bot_response_split  score
# 0                  [점수: 2, 이유: 모든 선분의 길이를 올바르게 구했다.]  점수: 2  \
# 1  [0점, 이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적...     0점
# 2  [1점, 이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 ...     1점
# 3        [점수: 2, 이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.]  점수: 2
# 4  [점수: 0, 이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적...  점수: 0
#
#                                               reason
# ...

# %%
# preprocessing in score column, erase "점수: "
df_2_3['score'] = df_2_3['score'].apply(lambda x: x.replace("점수: ", ""))

df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.  \
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...
#
#                                   bot_response_split score
# 0                  [점수: 2, 이유: 모든 선분의 길이를 올바르게 구했다.]     2  \
# 1  [0점, 이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적...    0점
# 2  [1점, 이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 ...    1점
# 3        [점수: 2, 이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.]     2
# 4  [점수: 0, 이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적...     0
#
#                                               reason
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_2_3['reason'] = df_2_3['reason'].apply(lambda x: x.replace("이유: ", ""))

df_2_3.head()
# Out:
#    user_id        user_answer
# 0        1      6m,  14m,  6m  \
# 1        2   6cm,  14cm,  6cm
# 2        3      6m,  14m,  6m
# 3        4      6m,  14m,  6m
# 4        5      6m,  14m,  6m
#
#                                         bot_response
# 0                    점수: 2\n이유: 모든 선분의 길이를 올바르게 구했다.  \
# 1   0점\n이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  1점\n이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따...
# 3          점수: 2\n이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  점수: 0\n이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어...
#
#                                   bot_response_split score
# 0                  [점수: 2, 이유: 모든 선분의 길이를 올바르게 구했다.]     2  \
# 1  [0점, 이유: 선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적...    0점
# 2  [1점, 이유: 정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 ...    1점
# 3        [점수: 2, 이유: 정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.]     2
# 4  [점수: 0, 이유: 문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적...     0
#
#                                               reason
# ...

# %%
df_2_3_pre = df_2_3[['user_id', 'user_answer', 'score', 'reason']]

df_2_3_pre.head()
# Out:
#    user_id        user_answer score
# 0        1      6m,  14m,  6m     2  \
# 1        2   6cm,  14cm,  6cm    0점
# 2        3      6m,  14m,  6m    1점
# 3        4      6m,  14m,  6m     2
# 4        5      6m,  14m,  6m     0
#
#                                               reason
# 0                               모든 선분의 길이를 올바르게 구했다.
# 1           선분의 기호와 이름을 적지 않았으며, 각 선분에 대응하는 길이만 적었다.
# 2  정답 중 2개만 일치하며, 선분의 기호와 이름이 주어진 요구사항에 따라 적혀있지 않...
# 3                     정답과 모든 선분의 길이가 일치하므로 올바른 답안이다.
# 4  문제의 요구사항을 충족하지 못했습니다. 선분 기호와 이름을 적어야 하지만, 답안에서...

# %%
df_2_3_pre_path = os.path.join(post_results_path, "number_2_3_eval_pre.tsv")

df_2_3_pre.to_csv(df_2_3_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 3-1

# %%
number_3_1_path = os.path.join(results_path, "number_3_1_eval.tsv")

print(number_3_1_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_3_1_eval.tsv

# %%
df_3_1 = pd.read_csv(number_3_1_path, sep="\t")

df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...

# %%
# \n\n -> \n
df_3_1['bot_response'] = df_3_1['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...

# %%
# df_1_1['bot_response'] split by \n
df_3_1['bot_response_split'] = df_3_1['bot_response'].apply(lambda x: x.split("\n"))
df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...  \
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...
#
#                                   bot_response_split
# ...

# %%
# make new two columns using bot_response_split column, which is a list
df_3_1['score'] = df_3_1['bot_response_split'].apply(lambda x: x[0])
df_3_1['reason'] = df_3_1['bot_response_split'].apply(lambda x: x[1])

df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...  \
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...
#
#                                   bot_response_split  score
# ...

# %%
# preprocessing in score column, erase "점수: "
df_3_1['score'] = df_3_1['score'].apply(lambda x: x.replace("점수: ", ""))

df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...  \
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...
#
#                                   bot_response_split score
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_3_1['reason'] = df_3_1['reason'].apply(lambda x: x.replace("이유: ", ""))

df_3_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가...  \
# 1  점수: 2\n이유: 정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성...
# 2  점수: 2\n이유: 정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로...
# 3              점수: 0\n이유: 정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  점수: 2\n이유: 정답인 60과 식 (6*6/2) + (14*6/2) = 60을 ...
#
#                                   bot_response_split score
# ...

# %%
df_3_1_pre = df_3_1[['user_id', 'user_answer', 'score', 'reason']]

df_3_1_pre.head()
# Out:
#    user_id                                        user_answer score
# 0        1                                  식: None\n풀이: None     0  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...     2
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...     2
# 3        4                                  식: None\n풀이: None     0
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...     2
#
#                                               reason
# 0  정답과 식이 제공되지 않았으며, 풀이에 대한 설명도 없다. 추가로 과정을 그림으로 ...
# 1  정답과 식을 정확히 서술한 경우로, 텃밭의 넓이를 계산하는데 성공하였다. 삼각형과 ...
# 2  정답과 식 모두 정확하게 작성하였고, 문제에서 요구하는 도형으로 텃밭을 나누고 넓이...
# 3                         정답과 식이 공란이고, 풀이도 제시되지 않았다.
# 4  정답인 60과 식 (6*6/2) + (14*6/2) = 60을 정확하게 썼으며, 삼...

# %%
df_3_1_pre_path = os.path.join(post_results_path, "number_3_1_eval_pre.tsv")

df_3_1_pre.to_csv(df_3_1_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 3-2

# %%
number_3_2_path = os.path.join(results_path, "number_3_2_eval.tsv")

print(number_3_2_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_3_2_eval.tsv

# %%
df_3_2 = pd.read_csv(number_3_2_path, sep="\t")

df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...

# %%
# \n\n -> \n
df_3_2['bot_response'] = df_3_2['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...

# %%
# df_1_1['bot_response'] split by \n
df_3_2['bot_response_split'] = df_3_2['bot_response'].apply(lambda x: x.split("\n"))
df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...  \
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...
#
#                                   bot_response_split
# ...

# %%
# make new two columns using bot_response_split column, which is a list
df_3_2['score'] = df_3_2['bot_response_split'].apply(lambda x: x[0])
df_3_2['reason'] = df_3_2['bot_response_split'].apply(lambda x: x[1])

df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...  \
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...
#
#                                   bot_response_split  score
# ...

# %%
# preprocessing in score column, erase "점수: "
df_3_2['score'] = df_3_2['score'].apply(lambda x: x.replace("점수: ", ""))

df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...  \
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...
#
#                                   bot_response_split score
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_3_2['reason'] = df_3_2['reason'].apply(lambda x: x.replace("이유: ", ""))

df_3_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...
# 3        4                                  식: None\n풀이: None
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...
#
#             user_picture_answer
# 0                           NaN  \
# 1            삼각형과 평행사변형으로 나눈 경우
# 2                 삼각형 3개로 나눈 경우
# 3  기타(직각삼각형, 사다리꼴, 삼각형으로 나눈 경우)
# 4                 삼각형 2개로 나눈 경우
#
#                                         bot_response
# 0  점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림...  \
# 1  점수: 2\n이유: 문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계...
# 2  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭...
# 3      점수: 0\n이유: 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  점수: 2\n이유: 학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘...
#
#                                   bot_response_split score
# ...

# %%
df_3_2_pre = df_3_2[['user_id', 'user_answer', 'score', 'reason']]

df_3_2_pre.head()
# Out:
#    user_id                                        user_answer score
# 0        1                                  식: None\n풀이: None     0  \
# 1        2  식: (6+14)*6/2=60\n풀이: 선분 ㄱㅂ과 선분 ㅂㄷ의 길이를 합하면 아랫...     2
# 2        3  식: {(아랫변) + (윗변)} * (높이) / 2\n풀이: ㄱ = 8 * 6 / ...     2
# 3        4                                  식: None\n풀이: None     0
# 4        5  식: (6*6/2) + (14*6/2) = 60\n풀이: (삼각형 넓이 = 밑변 *...     2
#
#                                               reason
# 0     도형을 나누어 해결하지 않았고, 정답과 식을 쓰지 않았다. 그림도 제출되지 않았다.
# 1  문제 해결 방법이 적절하게 사용되었으며, 정확한 식을 세우고 계산하여 정답을 도출한 경우
# 2  모범답안의 방법과 일치하여 사다리꼴을 삼각형 3개로 나누어 텃밭의 넓이를 계산하였다...
# 3                 도형을 나누어 해결하지 않았고, 정답과 식이 제시되지 않았다.
# 4  학생이 사다리꼴을 삼각형 2개로 나누어 넓이를 구하는 방법을 잘 따라했고, 정답도 ...

# %%
df_3_2_pre_path = os.path.join(post_results_path, "number_3_2_eval_pre.tsv")

df_3_2_pre.to_csv(df_3_2_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 4-1

# %%
number_4_1_path = os.path.join(results_path, "number_4_1_eval.tsv")

print(number_4_1_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_4_1_eval.tsv

# %%
df_4_1 = pd.read_csv(number_4_1_path, sep="\t")

df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.

# %%
# \n\n -> \n
df_4_1['bot_response'] = df_4_1['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.

# %%
# df_1_1['bot_response'] split by \n
df_4_1['bot_response_split'] = df_4_1['bot_response'].apply(lambda x: x.split("\n"))
df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...  \
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.
#
# ...

# %%
# make new two columns using bot_response_split column, which is a list
df_4_1['score'] = df_4_1['bot_response_split'].apply(lambda x: x[0])
df_4_1['reason'] = df_4_1['bot_response_split'].apply(lambda x: x[1])

df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...  \
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.
#
# ...

# %%
# preprocessing in score column, erase "점수: "
df_4_1['score'] = df_4_1['score'].apply(lambda x: x.replace("점수: ", ""))

df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...  \
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.
#
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_4_1['reason'] = df_4_1['reason'].apply(lambda x: x.replace("이유: ", ""))

df_4_1.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 ...  \
# 1  점수: 1\n이유: 정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직...
# 2                  점수: 2\n이유: 정답과 식을 정확히 서술하여 해결하였다.
# 3  점수: 2\n이유: 학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 ...
# 4                   점수: 1\n이유: 정답은 맞지만, 식은 제시되지 않았다.
#
# ...

# %%
df_4_1_pre = df_4_1[['user_id', 'user_answer', 'score', 'reason']]

df_4_1_pre.head()
# Out:
#    user_id                                        user_answer score
# 0        1                                  식: None\n풀이: None     1  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...     1
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...     2
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...     2
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...     1
#
#                                               reason
# 0       그림 답안의 전략은 올바르지만, 식으로 정리하지 않았고 풀이를 제공하지 않았다.
# 1  정답과 식이 완전히 제시되지 않았으나, 풀이 과정에서 덧붙인 직각삼각형의 넓이를 구...
# 2                             정답과 식을 정확히 서술하여 해결하였다.
# 3  학생이 정답과 식을 정확히 서술하였으며, 그림답안도 직각삼각형 두개를 덧붙여 직사각...
# 4                              정답은 맞지만, 식은 제시되지 않았다.

# %%
df_4_1_pre_path = os.path.join(post_results_path, "number_4_1_eval_pre.tsv")

df_4_1_pre.to_csv(df_4_1_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 4-2

# %%
number_4_2_path = os.path.join(results_path, "number_4_2_eval.tsv")

print(number_4_2_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_4_2_eval.tsv

# %%
df_4_2 = pd.read_csv(number_4_2_path, sep="\t")

df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...

# %%
# \n\n -> \n
df_4_2['bot_response'] = df_4_2['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...

# %%
# df_1_1['bot_response'] split by \n
df_4_2['bot_response_split'] = df_4_2['bot_response'].apply(lambda x: x.split("\n"))
df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...  \
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...
#
# ...

# %%
# make new two columns using bot_response_split column, which is a list
df_4_2['score'] = df_4_2['bot_response_split'].apply(lambda x: x[0])
df_4_2['reason'] = df_4_2['bot_response_split'].apply(lambda x: x[1])

df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...  \
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...
#
# ...

# %%
# preprocessing in score column, erase "점수: "
df_4_2['score'] = df_4_2['score'].apply(lambda x: x.replace("점수: ", ""))

df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...  \
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...
#
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_4_2['reason'] = df_4_2['reason'].apply(lambda x: x.replace("이유: ", ""))

df_4_2.head()
# Out:
#    user_id                                        user_answer
# 0        1                                  식: None\n풀이: None  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...
#
#                   user_picture_answer
# 0          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우  \
# 1          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 2          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 3          직각삼각형 두개를 덧붙여 직사각형을 만드는 경우
# 4  기타(직각삼각형 1개, 사다리꼴 1개, 삼각형 1개로 나눈다)
#
#                                         bot_response
# 0  점수: 1\n이유: 모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 ...  \
# 1  점수: 1\n이유: 사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 ...
# 2                        점수: 2\n이유: 모범답안의 방법과 일치한 경우
# 3  점수: 2\n이유: 모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직...
# 4  점수: 1\n이유: 모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리...
#
# ...

# %%
df_4_2_pre = df_4_2[['user_id', 'user_answer', 'score', 'reason']]

df_4_2_pre.head()
# Out:
#    user_id                                        user_answer score
# 0        1                                  식: None\n풀이: None     1  \
# 1        3  식: None\n풀이: ㄱ + ㄴ + ㄷ = 14 * 6 = 84, ㄱ = 5*6/...     1
# 2        4  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: (14*6) - (5*6...     2
# 3        5  식: (14*6) - (5*6/2 + 3*6/2)\n풀이: 삼각형 2개를 추가하여 ...     2
# 4        6  식: None\n풀이: 먼저 큰 사다리꼴을 삼각형 2개와 사다리꼴 1개로 바꾼다. ...     1
#
#                                               reason
# 0  모범답안의 방법과 다르게 직사각형으로 나누어 풀이했지만, 식을 세우지 않고 풀이 과...
# 1  사다리꼴의 넓이를 계산하는데 직각삼각형을 덧붙인 방식은 문제의 의도와는 다르지만, ...
# 2                                   모범답안의 방법과 일치한 경우
# 3  모범답안의 방법과 일치하여 사다리꼴 텃밭에 삼각형을 추가하여 직사각형으로 만들고 삼...
# 4  모법답안과 문제 해결방법이 다르지만, 사다리꼴을 삼각형과 사다리꼴로 나누는 방법으로...

# %%
df_4_2_pre_path = os.path.join(post_results_path, "number_4_2_eval_pre.tsv")

df_4_2_pre.to_csv(df_4_2_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 5-1

# %%
number_5_1_path = os.path.join(results_path, "number_5_1_eval.tsv")

print(number_5_1_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_5_1_eval.tsv

# %%
df_5_1 = pd.read_csv(number_5_1_path, sep="\t")

df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.

# %%
# \n\n -> \n
df_5_1['bot_response'] = df_5_1['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.

# %%
# df_1_1['bot_response'] split by \n
df_5_1['bot_response_split'] = df_5_1['bot_response'].apply(lambda x: x.split("\n"))
df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.  \
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.
#
#                                   bot_response_split
# 0     [점수: 0, 이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.]
# 1            [점수: 0, 이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.]
# 2  [점수: 0, 이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이...
# 3  [점수: 0, 이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 ...
# 4   [점수: 0, 이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.]

# %%
# make new two columns using bot_response_split column, which is a list
df_5_1['score'] = df_5_1['bot_response_split'].apply(lambda x: x[0])
df_5_1['reason'] = df_5_1['bot_response_split'].apply(lambda x: x[1])

df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.  \
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.
#
#                                   bot_response_split  score
# 0     [점수: 0, 이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.]  점수: 0  \
# 1            [점수: 0, 이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.]  점수: 0
# 2  [점수: 0, 이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이...  점수: 0
# 3  [점수: 0, 이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 ...  점수: 0
# ...

# %%
# preprocessing in score column, erase "점수: "
df_5_1['score'] = df_5_1['score'].apply(lambda x: x.replace("점수: ", ""))

df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.  \
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.
#
#                                   bot_response_split score
# 0     [점수: 0, 이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.]     0  \
# 1            [점수: 0, 이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.]     0
# 2  [점수: 0, 이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이...     0
# 3  [점수: 0, 이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 ...     0
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_5_1['reason'] = df_5_1['reason'].apply(lambda x: x.replace("이유: ", ""))

df_5_1.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0       점수: 0\n이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.  \
# 1              점수: 0\n이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  점수: 0\n이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나...
# 3  점수: 0\n이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않...
# 4     점수: 0\n이유: 정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.
#
#                                   bot_response_split score
# 0     [점수: 0, 이유: 정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.]     0  \
# 1            [점수: 0, 이유: 정답과 식이 제공되지 않았고, 그림답안도 없음.]     0
# 2  [점수: 0, 이유: 정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이...     0
# 3  [점수: 0, 이유: 정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 ...     0
# ...

# %%
df_5_1_pre = df_5_1[['user_id', 'user_answer', 'score', 'reason']]

df_5_1_pre.head()
# Out:
#    user_id        user_answer score
# 0        1  식: None\n풀이: None     0  \
# 1        2  식: None\n풀이: None     0
# 2        3  식: None\n풀이: None     0
# 3        4  식: None\n풀이: None     0
# 4        5  식: None\n풀이: None     0
#
#                                               reason
# 0                  정답과 식을 쓰지 않았으며, 그림답안도 제출하지 않았습니다.
# 1                         정답과 식이 제공되지 않았고, 그림답안도 없음.
# 2  정답과 식이 틀린 경우, 혹은 정답을 쓰지 않거나, None이나 NaN으로 표시되어...
# 3  정답과 식이 모두 제시되지 않았고, 그림답안도 표시되어 있지 않아 문제를 푼 흔적이...
# 4                정답과 식이 제시되지 않았으며 그림 답안도 확인할 수 없습니다.

# %%
df_5_1_pre_path = os.path.join(post_results_path, "number_5_1_eval_pre.tsv")

df_5_1_pre.to_csv(df_5_1_pre_path, sep="\t", index=False, encoding='utf-8')

# %% [markdown]
# # 5-2

# %%
number_5_2_path = os.path.join(results_path, "number_5_2_eval.tsv")

print(number_5_2_path)
# Out:
# /workspace/company/math_scoring_with_gpt/results/number_5_2_eval.tsv

# %%
df_5_2 = pd.read_csv(number_5_2_path, sep="\t")

df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.

# %%
# \n\n -> \n
df_5_2['bot_response'] = df_5_2['bot_response'].apply(lambda x: x.replace("\n\n", "\n"))

df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.

# %%
# df_1_1['bot_response'] split by \n
df_5_2['bot_response_split'] = df_5_2['bot_response'].apply(lambda x: x.split("\n"))
df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...  \
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.
#
#                                   bot_response_split
# 0  [점수: 0, 이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다...
# 1  [점수: 0, 이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며...
# 2            [점수: 0, 이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.]
# 3          [점수: 0, 이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.]
# 4         [점수: 0, 이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.]

# %%
# make new two columns using bot_response_split column, which is a list
df_5_2['score'] = df_5_2['bot_response_split'].apply(lambda x: x[0])
df_5_2['reason'] = df_5_2['bot_response_split'].apply(lambda x: x[1])

df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...  \
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.
#
#                                   bot_response_split  score
# 0  [점수: 0, 이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다...  점수: 0  \
# 1  [점수: 0, 이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며...  점수: 0
# 2            [점수: 0, 이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.]  점수: 0
# 3          [점수: 0, 이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.]  점수: 0
# ...

# %%
# preprocessing in score column, erase "점수: "
df_5_2['score'] = df_5_2['score'].apply(lambda x: x.replace("점수: ", ""))

df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...  \
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다...     0  \
# 1  [점수: 0, 이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며...     0
# 2            [점수: 0, 이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.]     0
# 3          [점수: 0, 이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.]     0
# ...

# %%
# preprocessing in reason column, erase "이유: "
df_5_2['reason'] = df_5_2['reason'].apply(lambda x: x.replace("이유: ", ""))

df_5_2.head()
# Out:
#    user_id        user_answer user_picture_answer
# 0        1  식: None\n풀이: None                 NaN  \
# 1        2  식: None\n풀이: None                 NaN
# 2        3  식: None\n풀이: None                 NaN
# 3        4  식: None\n풀이: None                 NaN
# 4        5  식: None\n풀이: None                 NaN
#
#                                         bot_response
# 0  점수: 0\n이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른...  \
# 1  점수: 0\n이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며,...
# 2              점수: 0\n이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3            점수: 0\n이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4           점수: 0\n이유: 문제를 해결하지 않았고, 정답과 관련된 내용이 없다.
#
#                                   bot_response_split score
# 0  [점수: 0, 이유: 정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다...     0  \
# 1  [점수: 0, 이유: 정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며...     0
# 2            [점수: 0, 이유: 문제를 풀지 않았으며, 답안과 그림답안이 없음.]     0
# 3          [점수: 0, 이유: 문제를 풀지 않았고, 그림 답안도 제공되지 않았다.]     0
# ...

# %%
df_5_2_pre = df_5_2[['user_id', 'user_answer', 'score', 'reason']]

df_5_2_pre.head()
# Out:
#    user_id        user_answer score
# 0        1  식: None\n풀이: None     0  \
# 1        2  식: None\n풀이: None     0
# 2        3  식: None\n풀이: None     0
# 3        4  식: None\n풀이: None     0
# 4        5  식: None\n풀이: None     0
#
#                                               reason
# 0  정답을 쓰지 않았고, 그림과 풀이도 제공하지 않았기 때문에 다른 도형으로 바꾸어 해...
# 1  정답을 작성하지 않았고, 문제 해결 방법에 대한 설명이 없으며, 그림 답안도 제출하...
# 2                         문제를 풀지 않았으며, 답안과 그림답안이 없음.
# 3                       문제를 풀지 않았고, 그림 답안도 제공되지 않았다.
# 4                      문제를 해결하지 않았고, 정답과 관련된 내용이 없다.

# %%
df_5_2_pre_path = os.path.join(post_results_path, "number_5_2_eval_pre.tsv")

df_5_2_pre.to_csv(df_5_2_pre_path, sep="\t", index=False, encoding='utf-8')
